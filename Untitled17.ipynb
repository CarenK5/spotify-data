# %% [markdown]
# <a href="https://colab.research.google.com/github/CarenK5/spotify-data/blob/master/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_tracks = pd.read_csv('/content/tracks.csv')
df_tracks.head()
# Out:
#                        id                                 name  popularity  \
# 0  35iwgR4jXetI318WEWsa1Q                                Carve           6
# 1  021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista           0
# 2  07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado           0
# 3  08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado           0
# 4  08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening           0
#
#    duration_ms  explicit              artists                  id_artists  \
# 0       126903         0              ['Uli']  ['45tIt06XoI0Iio4LBEVpls']
# 1        98200         0  ['Fernando Pessoa']  ['14jtPCOoNZwquk5wd9DxrY']
# 2       181640         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 3       176907         0  ['Ignacio Corsini']  ['5LiOoJbxVSAMkBS2fUm3X2']
# 4       163080         0      ['Dick Haymes']  ['3BiJGZsyX9sJchTqcSA7Su']
#
# ...

# %%
pd.isnull(df_tracks).sum()
# Out:
# id                  0
# name                0
# popularity          0
# duration_ms         0
# explicit            0
# artists             0
# id_artists          0
# release_date        0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      1
# dtype: int64

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19798 entries, 0 to 19797
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                19798 non-null  object
#  1   name              19798 non-null  object
#  2   popularity        19798 non-null  int64
#  3   duration_ms       19798 non-null  int64
#  4   explicit          19798 non-null  int64
#  5   artists           19798 non-null  object
#  6   id_artists        19798 non-null  object
#  7   release_date      19798 non-null  object
#  8   danceability      19798 non-null  float64
#  9   energy            19798 non-null  float64
#  10  key               19798 non-null  int64
#  11  loudness          19798 non-null  float64
#  12  mode              19798 non-null  int64
#  13  speechiness       19798 non-null  float64
#  14  acousticness      19798 non-null  float64
#  15  instrumentalness  19798 non-null  float64
# ...

# %%
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df
# Out:
#                            id  \
# 9898   1jTe9Tlzu2uYs85t0mWaWb
# 10145  3Ow7tjMRFTCCViesCZJ2nx
# 10146  3P6axadBqc4WVOg516IwEw
# 10147  3PEPaTaEMdlgqTlj1TAx1u
# 10148  3QH5IuHkiIqhceSZwcKmJj
# 10149  3QxmX2HrQbLAyB2qYqwcjA
# 10150  3RqFQtEkm0MnsKgIQfv0sG
# 10151  3SapM2pAFYGRpzujLujd5U
# 10152  3SecfMLRYe5noBS9h8dWcS
# 10153  3Spimi5VYsY8nfrVCdO6sF
#
#                                                     name  popularity  \
# 9898   Haydn: String Quartet No. 5 in F Major, Op. 3 ...           0
# 10145              Canaro - Instrumental (Remasterizado)           0
# 10146                                         Summertime           0
# 10147                                              Samba           0
# 10148  Symphony No. 8 in B Minor, D. 759 "Unfinished"...           0
# 10149                                  Mat Bhool Musafir           0
# 10150          Das ist bei uns nicht möglich, Kapitel 62           0
# 10151          Das ist bei uns nicht möglich, Kapitel 57           0
# ...

# %%
df_tracks.describe().transpose()
# Out:
#                     count           mean            std     min  \
# popularity        19798.0       2.306193       5.791890     0.0
# duration_ms       19798.0  204311.836347  147547.716349  3344.0
# explicit          19798.0       0.002576       0.050690     0.0
# danceability      19798.0       0.545826       0.170170     0.0
# energy            19798.0       0.270603       0.163781     0.0
# key               19798.0       5.100111       3.463034     0.0
# loudness          19798.0     -15.078783       5.436974   -60.0
# mode              19798.0       0.712244       0.452728     0.0
# speechiness       19798.0       0.221591       0.323215     0.0
# acousticness      19798.0       0.871056       0.207554     0.0
# instrumentalness  19798.0       0.309512       0.381783     0.0
# liveness          19798.0       0.216351       0.158502     0.0
# valence           19798.0       0.557762       0.249358     0.0
# tempo             19798.0     110.215214      31.261457     0.0
# ...

# %%
most_popular = df_tracks.query('popularity > 60').sort_values('popularity', ascending = False)[:10]

# %%
most_popular = df_tracks.query('popularity > 60').sort_values('popularity', ascending = False)
most_popular[:10]
# Out:
#                            id                       name  popularity  \
# 8095   1LGqJ3nvxpVXDWpEzq4DJD                  All of Me          65
# 18549  0qB213IfGN0JXXm9aRjldF  Again (with The Mellomen)          61
#
#        duration_ms  explicit                        artists  \
# 8095        181440         0             ['Billie Holiday']
# 18549       167907         0  ['Doris Day', 'The Mellomen']
#
#                                               id_artists release_date  \
# 8095                          ['1YzCsTRb22dQkh9lghPIrp']         1933
# 18549  ['3ESG6pj6a0LvUKklENalT6', '548L4DXlt7N14Mhbfd...         1945
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 8095          0.504  0.0644    2   -14.754     0       0.0408         0.972
# 18549         0.495  0.0209    3   -21.329     1       0.0348         0.981
#
#        instrumentalness  liveness  valence    tempo  time_signature
# ...

# %%
print(df_tracks['popularity'].unique())
# Out:
# [ 6  0  1  4 41 38 30 28 27 26 25 23 22 20 18 17 16 15 14 11 10  8  9  5
#   7  2 39 33 32 24 21 19 13 12  3 51 48 40 34 29 47 43 37 35 31 55 50 36
#  42 65 53 45 49 46 44 52 56 54 61]

# %%
df_tracks = pd.read_csv("/content/tracks.csv")

# %%
df_tracks.set_index("release_date", inplace=True)
df_tracks.index = pd.to_datetime(df_tracks.index)

# %%
df_tracks.head()
# Out:
#                                   id                                 name  \
# release_date
# 1922-02-22    35iwgR4jXetI318WEWsa1Q                                Carve
# 1922-06-01    021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 1922-03-21    07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 1922-03-21    08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 1922-01-01    08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
#
#               popularity  duration_ms  explicit              artists  \
# release_date
# 1922-02-22             6       126903         0              ['Uli']
# 1922-06-01             0        98200         0  ['Fernando Pessoa']
# 1922-03-21             0       181640         0  ['Ignacio Corsini']
# 1922-03-21             0       176907         0  ['Ignacio Corsini']
# 1922-01-01             0       163080         0      ['Dick Haymes']
#
# ...

# %%
df_tracks[["artists"]].iloc[60]
# Out:
# artists    ['Ignacio Corsini']
# Name: 1922-03-21 00:00:00, dtype: object

# %%
df_tracks["duration"]= df_tracks["duration_ms"]
df_tracks.drop("duration_ms", inplace=True, axis=1)

# %%
df_tracks.duration.head()
# Out:
# release_date
# 1922-02-22    126903
# 1922-06-01     98200
# 1922-03-21    181640
# 1922-03-21    176907
# 1922-01-01    163080
# Name: duration, dtype: int64
